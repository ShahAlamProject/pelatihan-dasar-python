# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahAlamProject/pelatihan-dasar-python/blob/main/belajarpythonday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
print("Selamat datang di ATM")
# Out:
# Selamat datang di ATM

# %%
saldo=100000
print(saldo)
# Out:
# 100000

# %%
setoran = input("Masukkan jumlah setoran:")
# Out:
# Masukkan jumlah setoran:1000000

# %%
#Saldo awal
saldo=100000
#Input setoran
setoran = int(input("Masukkann setoran:"))

jumlah_saldo = saldo + setoran
print(jumlah_saldo)
# Out:
# Masukkann setoran:200000
# 300000

# %%
a = 4
b = 2

habis_dibagi = a % b
print(habis_dibagi)
# Out:
# 0

# %%
print ("Selamat Datang di ATM")

saldo = 100000

setoran = int(input("Masukkan jumlah setoran :"))

jumlah_saldo = saldo + setoran

print("Saldo baru anda :", jumlah_saldo)
# Out:
# Selamat Datang di ATM
# Masukkan jumlah setoran :2000
# Saldo baru anda : 102000
