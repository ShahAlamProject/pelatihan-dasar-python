# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahAlamProject/pelatihan-dasar-python/blob/day-3/Modul_3_Jihad%20Zaidan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Project 5 Soal 1
IPK = float(input("Masukkan IPK Mahasiswa:"))

if IPK >= 3.51:
  print("Predikat: Dengan pujian (Cumlaude)")
elif IPK >= 2.76:
  print("Predikat: Sangat memuaskan")
else:
  print("Predikat: Memuaskan")
# Out:
# Masukkan IPK Mahasiswa:3.75
# Predikat: Dengan pujian (Cumlaude)

# %%
#Project 6 Soal 2
nilai = int(input("Masukkan nilai: "))

if nilai >= 60:
  print("Hasil: Lulus")
else:
  print("Hasil: Tidak Lulus")
# Out:
# Masukkan nilai: 75
# Hasil: Lulus
