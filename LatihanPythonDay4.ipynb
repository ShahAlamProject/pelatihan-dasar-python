# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahAlamProject/pelatihan-dasar-python/blob/day-4/LatihanPythonDay4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(3):
    print("Halo")
# Out:
# Halo
# Halo
# Halo

# %%
angka = [1, 2, 3, 4, 5]

for num in angka:
    print(f"Angka: {num}")
# Out:
# Angka: 1
# Angka: 2
# Angka: 3
# Angka: 4
# Angka: 5

# %%
hitung = 5

while hitung > 0:
    print(hitung)
    hitung -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
nilai = [80, 75, 90, 65, 88]

for n in nilai:
    if n >= 70:
        print(n, "Lulus")
    else:
        print(n, "Tidak Lulus")
# Out:
# 80 Lulus
# 75 Lulus
# 90 Lulus
# 65 Tidak Lulus
# 88 Lulus

# %%
def sapa(nama):
    print("Halo", nama)

sapa("Awan")
sapa("Budi")
sapa("Siti")
# Out:
# Halo Awan
# Halo Budi
# Halo Siti

# %%
def cek_lulus(nilai):
  if nilai >= 70:
    return "Lulus"
  else:
      return "Tidak Lulus"

nilai = [80, 65, 90, 55]

for n in nilai:
    print(n, cek_lulus(n))
# Out:
# 80 Lulus
# 65 Tidak Lulus
# 90 Lulus
# 55 Tidak Lulus
